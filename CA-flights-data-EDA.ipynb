# %%
import pandas as pd

# %%
df = pd.read_csv("CA-flights-2020-Q1.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421721 entries, 0 to 1421720
# Data columns (total 8 columns):
# ORIGIN_AIRPORT_ID        1421721 non-null int64
# ORIGIN_AIRPORT_SEQ_ID    1421721 non-null int64
# ORIGIN_CITY_MARKET_ID    1421721 non-null int64
# DEST_AIRPORT_ID          1421721 non-null int64
# DEST_AIRPORT_SEQ_ID      1421721 non-null int64
# DEST_CITY_MARKET_ID      1421721 non-null int64
# PASSENGERS               1421721 non-null float64
# Unnamed: 7               0 non-null float64
# dtypes: float64(2), int64(6)
# memory usage: 86.8 MB

# %%
df.head(10)
# Out:
#    ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# 0              10140                1014005                  30140
# 1              10140                1014005                  30140
# 2              10140                1014005                  30140
# 3              10140                1014005                  30140
# 4              10140                1014005                  30140
# 5              10140                1014005                  30140
# 6              10140                1014005                  30140
# 7              10140                1014005                  30140
# 8              10140                1014005                  30140
# 9              10140                1014005                  30140
#
#    DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  PASSENGERS  \
# 0            14771              1477104                32457         1.0
# 1            13796              1379608                32457         1.0
# ...

# %%
df['PASSENGERS'].values
# Out:
# array([ 1.,  1.,  1., ...,  2.,  1.,  1.])

# %%
df.describe()
# Out:
#        ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID  \
# count       1.421721e+06           1.421721e+06           1.421721e+06
# mean        1.338608e+04           1.338613e+06           3.221766e+04
# std         1.395944e+03           1.395940e+05           1.172308e+03
# min         1.014000e+04           1.014005e+06           3.014000e+04
# 25%         1.288900e+04           1.288903e+06           3.129500e+04
# 50%         1.379600e+04           1.379608e+06           3.245700e+04
# 75%         1.474700e+04           1.474703e+06           3.257500e+04
# max         1.621800e+04           1.621802e+06           3.538900e+04
#
#        DEST_AIRPORT_ID  DEST_AIRPORT_SEQ_ID  DEST_CITY_MARKET_ID  \
# count     1.421721e+06         1.421721e+06         1.421721e+06
# mean      1.338942e+04         1.338946e+06         3.221934e+04
# std       1.397457e+03         1.397453e+05         1.170690e+03
# min       1.014000e+04         1.014005e+06         3.014000e+04
# ...
