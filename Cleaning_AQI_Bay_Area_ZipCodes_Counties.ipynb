# %% [markdown]
# # Assigning the AQI values to Zip Codes and Counties
#
# ## Finding closest Station to a given zip code

# %%
import pandas as pd
import json
import numpy as np

# %%
# We load out zip code data file and make the index the zip code
zip_codes = pd.read_csv("Data/BA_ZIP_CODES.csv")
zip_codes.index = zip_codes["ZIP_CODE"]
zip_codes.head(5)
# Out:
#           ZIP_CODE  POPULATION_2010  HOUSING_2010  LAND_AREA_SQ_METER  \
# ZIP_CODE
# 94002        94002            25992         11108            14668197
# 94005        94005             4282          1934            11384384
# 94010        94010            40737         17348            30654438
# 94014        94014            47014         14284            16334952
# 94015        94015            60927         20678            14921282
#
#           LAND_AREA_SQ_MILES   LATITUDE   LONGITUDE     COUNTY
# ZIP_CODE
# 94002                  5.663  37.514352 -122.298896  San Mateo
# 94005                  4.396  37.688826 -122.408935  San Mateo
# 94010                 11.836  37.570280 -122.365778  San Mateo
# 94014                  6.307  37.690868 -122.447437  San Mateo
# 94015                  5.761  37.681267 -122.480591  San Mateo

# %%
#Loading Data about Bay Area Counties

with open('Data/BA_COUNTY_DATA.json') as f:
    BA_COUNTIES  = json.load(f)

BA_COUNTIES.keys()
# Out:
# dict_keys(['Alameda', 'Contra Costa', 'Marin', 'Napa', 'San Francisco', 'San Mateo', 'Santa Clara', 'Solano', 'Sonoma'])

# %% [markdown]
# We then load a clean-ish data set from AQS for all California Stations (https://www.epa.gov/outdoor-air-quality-data/download-daily-data))

# %%
#The Data was preliminary cleaned in Excel for superflous columns and rows
cali_AQI = pd.read_csv("Data/Cali_Stations_2015_2020_ave_max.csv")
cali_AQI['Date Local'] =pd.to_datetime(cali_AQI['Date Local']).round("D")
cali_AQI.head(5)
# Out:
#    Parameter Code  POC   Latitude   Longitude            Parameter Name  \
# 0           88101    3  37.687526 -121.784217  PM2.5 - Local Conditions
# 1           88101    3  37.687526 -121.784217  PM2.5 - Local Conditions
# 2           88101    3  37.743065 -122.169935  PM2.5 - Local Conditions
# 3           88101    3  37.743065 -122.169935  PM2.5 - Local Conditions
# 4           88101    3  37.814781 -122.282347  PM2.5 - Local Conditions
#
#   Sample Duration Pollutant Standard Date Local             Units of Measure  \
# 0          1 HOUR                NaN 2015-01-01  Micrograms/cubic meter (LC)
# 1   24-HR BLK AVG  PM25 24-hour 2012 2015-01-01  Micrograms/cubic meter (LC)
# 2          1 HOUR                NaN 2015-01-01  Micrograms/cubic meter (LC)
# 3   24-HR BLK AVG  PM25 24-hour 2012 2015-01-01  Micrograms/cubic meter (LC)
# 4          1 HOUR                NaN 2015-01-01  Micrograms/cubic meter (LC)
#
#   Event Type  Observation Count  Observation Percent  Arithmetic Mean  \
# 0       None                 24                  100        16.708333
# 1       None                  1                  100        16.700000
# 2       None                 24                  100        13.458333
# 3       None                  1                  100        13.400000
# 4       None                 24                  100        13.000000
#
#    1st Max Value  1st Max Hour   AQI  \
# 0           47.0            23   NaN
# 1           16.7             0  61.0
# 2           28.0             1   NaN
# 3           13.4             0  54.0
# 4           35.0            21   NaN
#
#                                          Method Name Local Site Name  \
# 0  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...       Livermore
# 1                                                 -        Livermore
# 2  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...         Oakland
# 3                                                 -          Oakland
# 4  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...    Oakland West
#
#   County Name Date of Last Change
# 0     Alameda            2/4/2016
# 1     Alameda            2/4/2016
# 2     Alameda            2/4/2016
# 3     Alameda            2/4/2016
# 4     Alameda            2/4/2016

# %% [markdown]
# We want to create a dictionary of all the stations in California to figure out what are the closest and second closest station to a given zip code.

# %%
cali_stations = cali_AQI.drop_duplicates(subset=['Local Site Name'], keep='last')[['Date Local','Local Site Name','County Name', 'Latitude','Longitude']].reset_index(drop=True)
cali_stations = cali_stations.sort_values(by='Local Site Name').reset_index(drop=True)
cali_stations.columns = ['END_DATE','NAME','COUNTY', 'LATITUDE', 'LONGITUDE']
cali_stations_f = cali_AQI.drop_duplicates(subset=['Local Site Name'])[['Date Local','Local Site Name','County Name', 'Latitude','Longitude']].sort_values(by='Local Site Name').reset_index(drop=True)
cali_stations['START_DATE'] = cali_stations_f['Date Local'].dt.strftime("%Y-%m-%d")
cali_stations['END_DATE'] = cali_stations['END_DATE'].dt.strftime("%Y-%m-%d")
cali_stations = cali_stations[['NAME','COUNTY', 'LATITUDE', 'LONGITUDE','START_DATE','END_DATE']]
cali_stations.index = cali_stations['NAME']
#cali_stations.head(5)
cali_stations
# Out:
#                                                                                                 NAME  \
# NAME
# 29 Palms                                                                                    29 Palms
# Anaheim                                                                                      Anaheim
# Arroyo Grande CDF                                                                  Arroyo Grande CDF
# Atascadero                                                                                Atascadero
# Atascadero (original site)                                                Atascadero (original site)
# ...                                                                                              ...
# White Mountain Research Center - Owens Valley Lab  White Mountain Research Center - Owens Valley Lab
# Willits-125 East Commercial Street                                Willits-125 East Commercial Street
# Woodland-Gibson Road                                                            Woodland-Gibson Road
# Yreka                                                                                          Yreka
# Yuba City                                                                                  Yuba City
#
#                                                             COUNTY   LATITUDE  \
# NAME
# 29 Palms                                                 Riverside  33.719690
# Anaheim                                                     Orange  33.830620
# Arroyo Grande CDF                                  San Luis Obispo  35.046730
# Atascadero                                         San Luis Obispo  35.494530
# Atascadero (original site)                         San Luis Obispo  35.491580
# ...                                                            ...        ...
# White Mountain Research Center - Owens Valley Lab             Inyo  37.360684
# Willits-125 East Commercial Street                       Mendocino  39.411740
# Woodland-Gibson Road                                          Yolo  38.661210
# Yreka                                                     Siskiyou  41.726892
# Yuba City                                                   Sutter  39.138773
#
#                                                     LONGITUDE  START_DATE  \
# NAME
# 29 Palms                                          -116.189700  2019-03-01
# Anaheim                                           -117.938450  2015-01-01
# Arroyo Grande CDF                                 -120.587770  2015-01-01
# Atascadero                                        -120.666170  2015-02-26
# Atascadero (original site)                        -120.668040  2015-01-01
# ...                                                       ...         ...
# White Mountain Research Center - Owens Valley Lab -118.330783  2015-04-01
# Willits-125 East Commercial Street                -123.352640  2015-01-01
# Woodland-Gibson Road                              -121.732690  2015-01-06
# Yreka                                             -122.633579  2015-02-08
# Yuba City                                         -121.618549  2015-01-01
#
#                                                      END_DATE
# NAME
# 29 Palms                                           2020-10-31
# Anaheim                                            2020-06-30
# Arroyo Grande CDF                                  2020-06-30
# Atascadero                                         2020-06-30
# Atascadero (original site)                         2015-02-23
# ...                                                       ...
# White Mountain Research Center - Owens Valley Lab  2020-06-30
# Willits-125 East Commercial Street                 2020-03-31
# Woodland-Gibson Road                               2020-07-26
# Yreka                                              2020-06-30
# Yuba City                                          2020-07-31
#
# [131 rows x 6 columns]

# %% [markdown]
# ## Function definitions
# Now we loop through all the zip codes and all the stations to find the nearest and second nearest station. But first we define an equation for calculating the distance bewtween two points using latitude and longitude

# %%
def dist_lat_long(lat1,long1,lat2,long2):
    latr1 = lat1/180*np.pi
    longr1 = long1/180*np.pi
    latr2 = lat2/180*np.pi
    longr2 = long2/180*np.pi
    # Using Haversine Formula (https://en.wikipedia.org/wiki/Haversine_formula). In km.
    dist = 2*6370*np.arcsin(np.sqrt(np.sin((latr2-latr1)/2)**2+np.cos(latr1)*np.cos(latr2)*np.sin((longr2-longr1)/2)**2))
    #Assuming a arth radius of 6370 km
    return dist

# %% [markdown]
# Additionally, we created a formula that calculates the Air Quality Index (AQI) based on the PM 2.5 concentration (https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf)

# %%
def calc_AQI(pm25):
    if pm25 < 12:
        aqi = round(0 + (50-0)/(12.0-0)*(pm25-0))
    elif pm25 <= 35.4:
        aqi = round(51 + (100-51)/(35.4-12.1)*(pm25-12.1))
    elif pm25 <= 55.4:
        aqi = round(101 + (150-101)/(55.4-35.5)*(pm25-5.5))
    elif pm25 <= 150.4:
        aqi = round(151 + (200-151)/(150.4-55.5)*(pm25-55.5))
    elif pm25 <= 250.4:
        aqi = round(201 + (300-201)/(250.4-150.5)*(pm25-150.5))
    elif pm25 <= 350.4:
        aqi = round(301 + (400-301)/(350.4-250.5)*(pm25-250.5))
    else:
        aqi = round(401 + (500-401)/(500.4-350.5)*(pm25-350.5))
    return aqi

# %% [markdown]
# Finally, we assigned a level of severity with the function **level_AQI** that corresponds to:
# <img src="Data/AQI_Values.jpg" alt="A Dataframe" style="width: 1000px;"/>

# %%
def level_AQI(aqi):
    if aqi <=50:
        level = 1
    elif aqi <=100:
        level = 2
    elif aqi <=150:
        level = 3
    elif aqi <=200:
        level = 4
    elif aqi <=300:
        level = 5
    else:
        level = 6
    return level

# %% [markdown]
# ## Assigning AQI Stations to Zip Codes
#
# Since there might be missing data, we are assigning a list of stations ordered by the distance to the center of the zip code

# %%
zip_codes['AQI_STATION_1'] = 'none'
zip_codes['AQI_D_KM_1'] = '100'
zip_codes['AQI_STATION_2'] = 'none'
zip_codes['AQI_D_KM_2'] = '100'
zip_codes['AQI_STATION_3'] = 'none'
zip_codes['AQI_D_KM_3'] = '100'
zip_codes['AQI_STATION_BA'] = 'none'
zip_codes['AQI_D_KM_BA'] = '100'
zip_codes['AQI_STATION_BA2'] = 'none'
zip_codes['AQI_D_KM_BA2'] = '100'
zip_codes['AQI_STATION_BA3'] = 'none'
zip_codes['AQI_D_KM_BA3'] = '100'
BA_counties = list(BA_COUNTIES.keys())

for zc in list(zip_codes.index):
        aq1,aq2,aq3,aqc, aqc2, aqc3 = 'none','none','none','none','none','none'
        dist1, dist2, dist3, distc, distc2, distc3 = 1000000,1000000,1000000,10000,1000,1000
        lat = zip_codes.at[zc,'LATITUDE']
        long = zip_codes.at[zc,'LONGITUDE']
        zcount = zip_codes.at[zc,'COUNTY']
        #print(zc,lat,long)
        for st in list(cali_stations.index):
            dist = dist_lat_long(lat,long,cali_stations.at[st,'LATITUDE'],cali_stations.at[st,'LONGITUDE'])
            coun = cali_stations.at[st,'COUNTY']
            #print(dist,st)
            if dist < dist1 :
                dist3 = dist2
                aq3 =aq2
                dist2 = dist1
                aq2 = aq1
                dist1 = dist.copy()
                aq1 = st
            elif dist < dist2:
                dist3 = dist2
                aq3 =aq2
                dist2 = dist.copy()
                aq2 = st
            elif dist < dist3:
                dist3 = dist
                aq3 = st
            if (dist < distc) & (coun in BA_counties):
                distc3 = distc2
                aqc3 = aqc2
                distc2 = distc
                aqc2 = aqc
                distc = dist.copy()
                aqc = st
            elif (dist < distc2) & (coun in BA_counties):
                distc3 = distc2
                aqc3 = aqc2
                distc2 = dist.copy()
                aqc2 = st
            elif (dist < distc3) & (coun in BA_counties):
                distc3 = dist
                aqc3 = st
        zip_codes.at[zc,'AQI_STATION_1'] = aq1
        zip_codes.at[zc,'AQI_STATION_2'] = aq2
        zip_codes.at[zc,'AQI_STATION_3'] = aq3
        zip_codes.at[zc,'AQI_STATION_BA'] = aqc
        zip_codes.at[zc,'AQI_STATION_BA2'] = aqc2
        zip_codes.at[zc,'AQI_STATION_BA3'] = aqc3
        zip_codes.at[zc,'AQI_D_KM_1'] = dist1
        zip_codes.at[zc,'AQI_D_KM_2'] = dist2
        zip_codes.at[zc,'AQI_D_KM_3'] = dist3
        zip_codes.at[zc,'AQI_D_KM_BA'] = distc
        zip_codes.at[zc,'AQI_D_KM_BA2'] = distc2
        zip_codes.at[zc,'AQI_D_KM_BA3'] = distc3
zip_codes
# Out:
#           ZIP_CODE  POPULATION_2010  HOUSING_2010  LAND_AREA_SQ_METER  \
# ZIP_CODE
# 94002        94002            25992         11108            14668197
# 94005        94005             4282          1934            11384384
# 94010        94010            40737         17348            30654438
# 94014        94014            47014         14284            16334952
# 94015        94015            60927         20678            14921282
# ...            ...              ...           ...                 ...
# 95625        95625              155            69             2991432
# 95687        95687            65096         22537           112718088
# 95688        95688            34379         12997           210272010
# 95690        95690             2533          1123           148353474
# 95694        95694             9156          3274           386439555
#
#           LAND_AREA_SQ_MILES   LATITUDE   LONGITUDE     COUNTY  \
# ZIP_CODE
# 94002                  5.663  37.514352 -122.298896  San Mateo
# 94005                  4.396  37.688826 -122.408935  San Mateo
# 94010                 11.836  37.570280 -122.365778  San Mateo
# 94014                  6.307  37.690868 -122.447437  San Mateo
# 94015                  5.761  37.681267 -122.480591  San Mateo
# ...                      ...        ...         ...        ...
# 95625                  1.155  38.358121 -121.911547     Solano
# 95687                 43.521  38.333133 -121.920151     Solano
# 95688                 81.186  38.408571 -122.022775     Solano
# 95690                 57.280  38.199576 -121.618273     Solano
# 95694                149.205  38.568491 -122.080210     Solano
#
#                  AQI_STATION_1 AQI_D_KM_1  \
# ZIP_CODE
# 94002             Redwood City    9.12116
# 94005            San Francisco    8.61801
# 94010             Redwood City    17.3019
# 94014            San Francisco    9.36909
# 94015            San Francisco    11.8345
# ...                        ...        ...
# 95625      Napa Valley College    32.9072
# 95687      Napa Valley College    31.5426
# 95688                     Napa    26.1906
# 95690        Stockton-Hazelton    41.2589
# 95694     Woodland-Gibson Road    31.9003
#
#                                         AQI_STATION_2 AQI_D_KM_2  \
# ZIP_CODE
# 94002                                         Oakland    27.8479
# 94005                                   Laney College    17.3066
# 94010                                   San Francisco    21.9498
# 94014                                   Laney College    19.8082
# 94015                                   Laney College    22.8204
# ...                                               ...        ...
# 95625                                            Napa    33.9514
# 95687                                            Napa    32.8918
# 95688                             Napa Valley College    26.3019
# 95690     Sacramento Health Department-Stockton Blvd.     42.036
# 95694                                            Napa     34.258
#
#                      AQI_STATION_3 AQI_D_KM_3       AQI_STATION_BA  \
# ZIP_CODE
# 94002                San Francisco    29.3282         Redwood City
# 94005                 Oakland West    17.8863        San Francisco
# 94010                      Oakland    25.8099         Redwood City
# 94014                 Oakland West    20.0096        San Francisco
# 94015                 Oakland West    22.8922        San Francisco
# ...                            ...        ...                  ...
# 95625         Woodland-Gibson Road    37.1157  Napa Valley College
# 95687                      Vallejo    37.7905  Napa Valley College
# 95688         Woodland-Gibson Road    37.7538                 Napa
# 95690     Sacramento-1309 T Street    42.4352              Concord
# 95694          Napa Valley College    36.3988                 Napa
#
#          AQI_D_KM_BA      AQI_STATION_BA2 AQI_D_KM_BA2      AQI_STATION_BA3  \
# ZIP_CODE
# 94002        9.12116              Oakland      27.8479        San Francisco
# 94005        8.61801        Laney College      17.3066         Oakland West
# 94010        17.3019        San Francisco      21.9498              Oakland
# 94014        9.36909        Laney College      19.8082         Oakland West
# 94015        11.8345        Laney College      22.8204         Oakland West
# ...              ...                  ...          ...                  ...
# 95625        32.9072                 Napa      33.9514              Vallejo
# 95687        31.5426                 Napa      32.8918              Vallejo
# 95688        26.1906  Napa Valley College      26.3019              Vallejo
# 95690        46.1863              Vallejo      55.2438  Napa Valley College
# 95694         34.258  Napa Valley College      36.3988              Vallejo
#
#          AQI_D_KM_BA3
# ZIP_CODE
# 94002         29.3282
# 94005         17.8863
# 94010         25.8099
# 94014         20.0096
# 94015         22.8922
# ...               ...
# 95625         40.2532
# 95687         37.7905
# 95688         38.8695
# 95690         58.0223
# 95694         53.6026
#
# [305 rows x 20 columns]

# %% [markdown]
# From the list of stations, we can determine which are the AQI stations that feed into the Bay Area

# %%
BA_ind = list(pd.concat([zip_codes['AQI_STATION_1'],zip_codes['AQI_STATION_2'],zip_codes['AQI_STATION_3']]).unique())

BA_stations = cali_stations.loc[BA_ind]

BA_stations.to_csv('Data/BA_AQI_STATIONS.csv', index=False)

BA_stations = BA_stations.sort_index()

with open('Data/BA_AQI_STATIONS.json', 'w', encoding='utf-8') as f:
    json.dump(BA_stations[['NAME','COUNTY','LATITUDE','LONGITUDE']].to_dict('index'), f, ensure_ascii=False, indent=4)

BA_stations
# Out:
#                                                                                     NAME  \
# NAME
# Berkeley Aquatic Park                                              Berkeley Aquatic Park
# Concord                                                                          Concord
# Cortina Indian Rancheria                                        Cortina Indian Rancheria
# Gilroy                                                                            Gilroy
# Hollister                                                                      Hollister
# Livermore                                   -121.784217  2015-01-01
# Manteca                                     -121.247874  2015-01-01
# Napa                                        -122.296189  2015-01-01
# Napa Valley College                         -122.275024  2018-04-01
# Oakland                                     -122.169935  2015-01-01
# Oakland West                                -122.282347  2015-01-01
# Pleasanton - Owens Ct                       -121.903019  2018-04-03
# Redwood City                                -122.203370  2015-01-01
# Sacramento Health Department-Stockton Blvd. -121.458499  2015-01-03
# Sacramento-1309 T Street                    -121.493110  2015-01-01
# Sacramento-Bercut Drive                     -121.503795  2016-12-02
# Salinas 3                                   -121.623271  2015-01-01
# San Francisco                               -122.399044  2015-01-01
# San Jose - Jackson                          -121.894898  2015-01-01
# San Jose - Knox Avenue                      -121.849783  2015-01-01
# San Lorenzo Valley Middle School            -122.083092  2015-01-01
# San Pablo                                   -122.356811  2015-01-01
# San Rafael                                  -122.520004  2015-01-01
# Santa Cruz                                  -121.988220  2015-01-01
# Sebastopol                                  -122.818294  2015-01-01
# Stockton-Hazelton                           -121.268523  2015-01-01
# Ukiah-Library                               -123.206550  2015-01-01
# Vallejo                                     -122.237976  2015-01-01
# Woodland-Gibson Road                        -121.732690  2015-01-06
#
#                                                END_DATE
# NAME
# Berkeley Aquatic Park                        2020-08-31
# Concord                                      2020-08-31
# Cortina Indian Rancheria                     2020-09-15
# Gilroy                                       2020-08-31
# Hollister                                    2020-06-30
# Lakeport-Lakeport Blvd.                      2017-06-30
# Lakeport-S. Main Street                      2020-06-26
# Laney College                                2020-08-31
# Livermore                                    2020-08-31
# Manteca                                      2020-09-30
# Napa                                         2018-03-31
# Napa Valley College                          2020-08-31
# Oakland                                      2020-08-31
# Oakland West                                 2020-08-31
# Pleasanton - Owens Ct                        2020-08-31
# Redwood City                                 2020-08-31
# Sacramento Health Department-Stockton Blvd.  2016-11-14
# Sacramento-1309 T Street                     2020-07-30
# Sacramento-Bercut Drive                      2020-07-29
# Salinas 3                                    2020-06-30
# San Francisco                                2020-08-31
# San Jose - Jackson                           2020-08-31
# San Jose - Knox Avenue                       2020-07-31
# San Lorenzo Valley Middle School             2020-06-30
# San Pablo                                    2020-08-31
# San Rafael                                   2020-08-31
# Santa Cruz                                   2020-06-30
# Sebastopol                                   2020-08-31
# Stockton-Hazelton                            2020-07-31
# Ukiah-Library                                2020-03-31
# Vallejo                                      2020-08-31
# Woodland-Gibson Road                         2020-07-26

# %% [markdown]
# Now we will clean out dataset to only include data from the stations that feed the bay area

# %%
indaqi = []
ir = np.array(cali_AQI['Local Site Name']=='0')
#print(list(cali_AQI['Site Name'].unique()))

for iq in list(BA_stations['NAME']):
    ib = np.array(cali_AQI['Local Site Name']==iq)
    #print(iq,np.sum(ib))
    ir = np.logical_or(ir,ib)
#print(ir)
#print('All',np.sum(ir))
## Keeping relevant stations and kepping first observation
BA_AQI = cali_AQI.loc[ir].drop_duplicates(subset=['POC', 'Date Local','Local Site Name'], keep='first')[['Local Site Name','POC','Date Local', \
                                                'Observation Count','Arithmetic Mean','1st Max Value', 'Parameter Name','Units of Measure','Method Name']]

BA_AQI.to_csv('Data/BA_AQI_DATA.csv', index=False) 
BA_AQI.head(5)
# Out:
#              Local Site Name  POC Date Local  Observation Count  \
# 0                  Livermore    3 2015-01-01                 24
# 2                    Oakland    3 2015-01-01                 24
# 4               Oakland West    3 2015-01-01                 24
# 6              Laney College    3 2015-01-01                 24
# 11  Cortina Indian Rancheria    1 2015-01-01                 24
#
#     Arithmetic Mean  1st Max Value            Parameter Name  \
# 0         16.708333           47.0  PM2.5 - Local Conditions
# 2         13.458333           28.0  PM2.5 - Local Conditions
# 4         13.000000           35.0  PM2.5 - Local Conditions
# 6         10.750000           42.0  PM2.5 - Local Conditions
# 11         4.708333            9.0  PM2.5 - Local Conditions
#
#                Units of Measure  \
# 0   Micrograms/cubic meter (LC)
# 2   Micrograms/cubic meter (LC)
# 4   Micrograms/cubic meter (LC)
# 6   Micrograms/cubic meter (LC)
# 11  Micrograms/cubic meter (LC)
#
#                                           Method Name
# 0   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 2   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 4   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 6   Met One BAM-1020 Mass Monitor w/VSCC - Beta At...
# 11  Met One BAM-1020 Mass Monitor w/VSCC - Beta At...

# %%
# Checking for null values
BA_AQI['1st Max Value'].isnull().sum()
# Out:
# 0

# %%
# Checking for null values
BA_AQI['Arithmetic Mean'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Now, we will create a dictionary for each relevant station that it is also a dictionary, that includes the air quality data by date

# %%
# Creating a Station Dictionary

station_dict = BA_stations.to_dict('index')
BA_stations['MISSING_VALUES'] = 0
date_range = list(BA_AQI['Date Local'].dt.strftime("%Y-%m-%d").unique())
n_date = len(date_range)

for st in station_dict:
    station_dict[st]['AQI'] = {}
    ind = list(BA_AQI.loc[BA_AQI['Local Site Name']==st].index)
    for dind in ind:
        ks = BA_AQI.loc[dind,'Date Local'].strftime("%Y-%m-%d")
        if ks in station_dict[st]['AQI']:
            #print('Double values for station',st,' at date ',ks)
            #print(station_dict[st]['AQI'][ks])
            station_dict[st]['AQI'][ks]['AVE_PM_2.5'] = (station_dict[st]['AQI'][ks]['AVE_PM_2.5']+ \
                BA_AQI.loc[dind,'Arithmetic Mean'])/2
            maxa =  max(list([station_dict[st]['AQI'][ks]['MAX_PM_2.5'],BA_AQI.loc[dind,'1st Max Value']]))
            station_dict[st]['AQI'][ks]['MAX_PM_2.5'] = maxa
            station_dict[st]['AQI'][ks]['24hr_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['AVE_PM_2.5'])
            station_dict[st]['AQI'][ks]['Max_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['MAX_PM_2.5'])
        else:
            station_dict[st]['AQI'][ks] = {'AVE_PM_2.5':BA_AQI.loc[dind,'Arithmetic Mean'], }
            station_dict[st]['AQI'][ks]['MAX_PM_2.5'] = BA_AQI.loc[dind,'1st Max Value']
            station_dict[st]['AQI'][ks]['24hr_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['AVE_PM_2.5'])
            station_dict[st]['AQI'][ks]['Max_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['MAX_PM_2.5'])
    BA_stations.loc[st,"MISSING_VALUES"] = n_date - len(station_dict[st]['AQI'].keys())
    
BA_stations.sort_index()
# Out:
#                                                                                     NAME  \
# NAME
# Berkeley Aquatic Park                                              Berkeley Aquatic Park
#cali_AQI_new['Station'].sort_values().unique()
# Out:
#         Date                 Station  Average  Maximum  Source
# 0 2020-10-01               San Pablo     38.3     61.0  BAAQMD
# 1 2020-10-01            Redwood City     45.7     65.0  BAAQMD
# 2 2020-10-01   Pleasanton - Owens Ct     62.7     94.0  BAAQMD
# 3 2020-10-01  San Jose - Knox Avenue     69.2     93.0  BAAQMD
# 4 2020-10-01                 Oakland     58.7    122.0  BAAQMD

# %%
#CLeaning the data and removing duplicates
indaqi = []
ir = np.array(cali_AQI_new['Station']=='0')
#print(list(cali_AQI['Site Name'].unique()))

for iq in list(BA_stations['NAME']):
    ib = np.array(cali_AQI_new['Station']==iq)
    #print(iq,np.sum(ib))
    ir = np.logical_or(ir,ib)
#print(ir)
#print('All',np.sum(ir))
## Keeping relevant stations and kepping first observation
BA_AQI_new = cali_AQI_new.loc[ir].drop_duplicates(subset=['Date','Station'], keep='first').sort_values(by=['Date']).reset_index(drop=True)
BA_AQI_new.to_csv('Data/BA_AQI_DATA_2020.csv', index=False) 
BA_AQI_new.head(5)
#BA_AQI_new['Station'].unique()
# Out:
#         Date                           Station  Average  Maximum Source
# 0 2020-01-01               Napa Valley College     12.6     12.6    AQS
# 1 2020-01-01          Sacramento-1309 T Street     24.5     24.5    AQS
# 2 2020-01-01                        Sebastopol     12.1     12.1    AQS
# 3 2020-01-01                           Vallejo     14.5     14.5    AQS
# 4 2020-01-01  San Lorenzo Valley Middle School      6.5      6.5    AQS

# %%
date_range = list(BA_AQI_new['Date'].dt.strftime("%Y-%m-%d").unique())
date_range_all = list(pd.concat([BA_AQI['Date Local'],BA_AQI_new['Date']]).unique().sort_values().dt.strftime("%Y-%m-%d"))
n_date = len(date_range_all)
for st in station_dict:
    ind = list(BA_AQI_new.loc[BA_AQI_new['Station']==st].index)
    for dind in ind:
        ks = BA_AQI_new.loc[dind,'Date'].strftime("%Y-%m-%d")
        if ks not in station_dict[st]['AQI']:
            station_dict[st]['AQI'][ks] = {}
            station_dict[st]['AQI'][ks]['AVE_PM_2.5'] = BA_AQI_new.loc[dind,'Average']
            station_dict[st]['AQI'][ks]['MAX_PM_2.5'] = BA_AQI_new.loc[dind,'Maximum']
            station_dict[st]['AQI'][ks]['24hr_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['AVE_PM_2.5'])
            station_dict[st]['AQI'][ks]['Max_AQI'] = calc_AQI(station_dict[st]['AQI'][ks]['MAX_PM_2.5'])
    BA_stations.loc[st,"MISSING_VALUES"] = n_date - len(station_dict[st]['AQI'].keys())
    BA_stations.loc[st,"END_DATE"] = max(station_dict[st]['AQI'].keys())
    
BA_stations.sort_values(by=['COUNTY'])
# Out:
#                                                                                     NAME  \
# NAME
# Berkeley Aquatic Park                                              Berkeley Aquatic Park
# Pleasanton - Owens Ct                                              Pleasanton - Owens Ct
# Oakland West                                                                Oakland West
# Oakland                                                                          Oakland
# Livermore                                                                      Livermore
# Laney College                                                              Laney College
# Cortina Indian Rancheria                                        Cortina Indian Rancheria
# San Pablo                                                                      San Pablo
# Concord                                                                          Concord
# Lakeport-Lakeport Blvd.                                          Lakeport-Lakeport Blvd.
# Salinas 3                                   -121.623271  2015-01-01
# Napa                                        -122.296189  2015-01-01
# Napa Valley College                         -122.275024  2018-04-01
# Sacramento Health Department-Stockton Blvd. -121.458499  2015-01-03
# Sacramento-1309 T Street                    -121.493110  2015-01-01
# Sacramento-Bercut Drive                     -121.503795  2016-12-02
# Hollister                                   -121.362100  2015-01-01
# San Francisco                               -122.399044  2015-01-01
# Manteca                                     -121.247874  2015-01-01
# Stockton-Hazelton                           -121.268523  2015-01-01
# Redwood City                                -122.203370  2015-01-01
# San Jose - Knox Avenue                      -121.849783  2015-01-01
# San Jose - Jackson                          -121.894898  2015-01-01
# Gilroy                                      -121.574684  2015-01-01
# Santa Cruz                                  -121.988220  2015-01-01
# San Lorenzo Valley Middle School            -122.083092  2015-01-01
# Vallejo                                     -122.237976  2015-01-01
# Sebastopol                                  -122.818294  2015-01-01
# Woodland-Gibson Road                        -121.732690  2015-01-06
#
#                                                END_DATE  MISSING_VALUES
# NAME
# Berkeley Aquatic Park                        2020-12-03             579
# Pleasanton - Owens Ct                        2020-12-03            1198
# Oakland West                                 2020-12-03              59
# Oakland                                      2020-12-03              12
# Livermore                                    2020-12-03              15
# Laney College                                2020-12-03               6
# Cortina Indian Rancheria                     2020-09-15             369
# San Pablo                                    2020-12-03              39
# Concord                                      2020-12-03              35
# Lakeport-Lakeport Blvd.                      2017-06-30            2012
# Lakeport-S. Main Street                      2020-06-26            1987
# San Rafael                                   2020-12-03              55
# Ukiah-Library                                2020-03-31             255
# Salinas 3                                    2020-12-03              16
# Napa                                         2018-03-31             994
# Napa Valley College                          2020-12-03            1196
# Sacramento Health Department-Stockton Blvd.  2016-11-14            1950
# Sacramento-1309 T Street                     2020-12-03            1158
# Sacramento-Bercut Drive                      2020-07-29            1759
# Hollister                                    2020-12-03              19
# San Francisco                                2020-12-01              25
# Manteca                                      2020-12-03              74
# Stockton-Hazelton                            2020-12-03              21
# Redwood City                                 2020-12-03              26
# San Jose - Knox Avenue                       2020-12-03              15
# San Jose - Jackson                           2020-12-03              26
# Gilroy                                       2020-12-03              41
# Santa Cruz                                   2020-12-03              19
# San Lorenzo Valley Middle School             2020-12-03              49
# Vallejo                                      2020-12-03              44
# Sebastopol                                   2020-12-03              34
# Woodland-Gibson Road                         2020-07-26            1858

# %%
with open('Data/BA_AQI_STATIONS.json', 'w', encoding='utf-8') as f:
    json.dump(station_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# Now we can loop through the zip codes and assign the AQI value of the clossest station with data to the station. If none of the clossest station has a value for the date, we interpolate with the closest dates that have values.

# %%
zip_dict = zip_codes.to_dict('index')
date_range = list(pd.concat([BA_AQI['Date Local'],BA_AQI_new['Date']]).sort_values().dt.strftime("%Y-%m-%d").unique())
problem_zip = [];
nd = len(date_range)

for zc in zip_dict:
    zip_dict[zc]['AQI']={}
    for izd in range(nd):
        zdate = date_range[izd]
        zip_dict[zc]['AQI'][zdate] = {}
        st = []
        if zdate in station_dict[zip_dict[zc]["AQI_STATION_1"]]['AQI']:
            st = zip_dict[zc]["AQI_STATION_1"]
        elif zdate in station_dict[zip_dict[zc]["AQI_STATION_2"]]['AQI']:
            st = zip_dict[zc]["AQI_STATION_2"]
        elif zdate in station_dict[zip_dict[zc]["AQI_STATION_3"]]['AQI']:
            st = zip_dict[zc]["AQI_STATION_3"]
        elif zdate in station_dict[zip_dict[zc]["AQI_STATION_BA"]]['AQI']:
            st = zip_dict[zc]["AQI_STATION_BA"]
        if not st:
            step = 3
            zdate1 = date_range[(izd-step)]
            if (izd+step)< nd:
                zdate2 = date_range[(izd+step)]
            elif izd == nd:
                zdate2 = zdate1
            else:
                zdate2 = date_range[(nd-1)]
            
            if (zdate2 in station_dict[zip_dict[zc]["AQI_STATION_1"]]['AQI']) and (zdate1 in station_dict[zip_dict[zc]["AQI_STATION_1"]]['AQI']):
                st = zip_dict[zc]["AQI_STATION_1"]
            elif (zdate2 in station_dict[zip_dict[zc]["AQI_STATION_2"]]['AQI']) and (zdate1 in station_dict[zip_dict[zc]["AQI_STATION_2"]]['AQI']):
                st = zip_dict[zc]["AQI_STATION_2"]
            elif (zdate2 in station_dict[zip_dict[zc]["AQI_STATION_3"]]['AQI']) and (zdate1 in station_dict[zip_dict[zc]["AQI_STATION_3"]]['AQI']):
                st = zip_dict[zc]["AQI_STATION_3"]
            elif (zdate2 in station_dict[zip_dict[zc]["AQI_STATION_BA"]]['AQI']) and (zdate1 in station_dict[zip_dict[zc]["AQI_STATION_BA"]]['AQI']):
                st = zip_dict[zc]["AQI_STATION_BA"]
            elif (zdate2 in station_dict[zip_dict[zc]["AQI_STATION_BA2"]]['AQI']) and (zdate1 in station_dict[zip_dict[zc]["AQI_STATION_BA2"]]['AQI']):
                st = zip_dict[zc]["AQI_STATION_BA2"]
            else:
                st = zip_dict[zc]["AQI_STATION_BA3"]
            
            #print('interpolating for zip code and date at station',zc,zdate,st)
          
            n = 0
            zdate1 = zdate
            while zdate1 not in station_dict[st]['AQI']:
                n = n+1
                if (izd-n)> 0:
                    zdate1 = date_range[(izd-n)]
                else:
                    problem_zip.append(zc)
                    print('Weird things going on in start date for',zc,zdate)
                    break
            
            n = 0
            zdate2 = zdate
            while zdate2 not in station_dict[st]['AQI']:
                n = n+1
                if (izd+n)< nd:
                    zdate2= date_range[(izd+n)]
                else:
                    zdate2 = zdate1
                    problem_zip.append(zc)
            
            
            for kd in station_dict[st]['AQI'][zdate1].keys():
                if not isinstance(station_dict[st]['AQI'][zdate2][kd],str):
                    #print('Values for ', zc, kd, station_dict[st]['AQI'][zdate1][kd],type(station_dict[st]['AQI'][zdate2][kd]))
                    zip_dict[zc]['AQI'][zdate][kd] = round((station_dict[st]['AQI'][zdate1][kd]+
                                                           station_dict[st]['AQI'][zdate2][kd])/2)
                else:
                    zip_dict[zc]['AQI']['AQI'][zdate][kd] = station_dict[st]['AQI'][zdate1][kd].copy()
        else:
            zip_dict[zc]['AQI'][zdate] = station_dict[st]['AQI'][zdate].copy()
            zip_dict[zc]['AQI'][zdate].update({'STATION':st})
           
problem_zip = zip_codes.loc[list(set(problem_zip))]

# %%
station_dict[zip_dict[zc]["AQI_STATION_3"]]['AQI'][date_range[(izd+3)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-fad4fbaa55a0> in <module>
# ----> 1 station_dict[zip_dict[zc]["AQI_STATION_3"]]['AQI'][date_range[(izd+3)]]
#
# KeyError: '2015-04-19'

# %%
with open('Data/BA_AQI_ZIP_CODES.json', 'w', encoding='utf-8') as f:
    json.dump(zip_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## AQI for Each Bay Area County
# Now we can get the values for each county based on the weighted average of the zip codes based on each zipcode area

# %%
date_range = list(pd.concat([BA_AQI['Date Local'],BA_AQI_new['Date']]).sort_values().dt.strftime("%Y-%m-%d").unique())
nd = len(date_range)

for c in BA_COUNTIES:
    zca = list(BA_COUNTIES[c]['ZIP_CODES'])
    w_zca = []
    BA_COUNTIES[c]['AQI'] = {'AVE_PM_2.5':{},'MAX_PM_2.5':{},'24hr_AQI':{},'Max_AQI':{},'AQI_LEVEL':{},'AQI_LEVEL_MAX':{}}
    for zc in zca:
        w_zca.append(zip_dict[zc]['LAND_AREA_SQ_MILES']/BA_COUNTIES[c]['LAND_AREA_SQ_MILES'])
    for ks in date_range:
        aveq,maxq = 0,0
        for zc in range(len(zca)):
            aveq = aveq + w_zca[zc]*zip_dict[zca[zc]]['AQI'][ks]['AVE_PM_2.5']
            maxq = max([maxq,zip_dict[zca[zc]]['AQI'][ks]['MAX_PM_2.5']])
        BA_COUNTIES[c]['AQI']['AVE_PM_2.5'][ks] = aveq
        BA_COUNTIES[c]['AQI']['MAX_PM_2.5'][ks] = maxq
        BA_COUNTIES[c]['AQI']['24hr_AQI'][ks] = calc_AQI(aveq)
        BA_COUNTIES[c]['AQI']['Max_AQI'][ks] = calc_AQI(maxq)
        BA_COUNTIES[c]['AQI']['AQI_LEVEL'][ks] = level_AQI(BA_COUNTIES[c]['AQI']['24hr_AQI'][ks])
        BA_COUNTIES[c]['AQI']['AQI_LEVEL_MAX'][ks] = level_AQI(BA_COUNTIES[c]['AQI']['Max_AQI'][ks])

# %%
with open('Data/BA_AQI_COUNTIES.json', 'w', encoding='utf-8') as f:
    json.dump(BA_COUNTIES, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## AQI for Bay Area as a Whole
#
# We will average by both area and population.

# %%
date_range = list(pd.concat([BA_AQI['Date Local'],BA_AQI_new['Date']]).sort_values().dt.strftime("%Y-%m-%d").unique())
nd = len(date_range)
BA_area = 0
BA_pop = 0
w_zca = []
w_zcp = []
zca = list(zip_dict.keys())

for zc in zip_dict:
    BA_area = BA_area + zip_dict[zc]['LAND_AREA_SQ_MILES']
    BA_pop = BA_pop +  zip_dict[zc]['POPULATION_2010']
BA = {}
for zc in zip_dict:
        w_zca.append(zip_dict[zc]['LAND_AREA_SQ_MILES']/BA_area)
        w_zcp.append(zip_dict[zc]['POPULATION_2010']/BA_pop)
for ks in date_range:
        BA[ks] = {}
        aveqa,maxqa,aveqp = 0,0,0
        ag, amod, auhsg, auh, avuh,ah =0,0,0,0,0,0
        pg, pmod, puhsg, puh, pvuh,ph =0,0,0,0,0,0
        mag, mamod, mauhsg, mauh, mavuh,mah =0,0,0,0,0,0
        mpg, mpmod, mpuhsg, mpuh, mpvuh,mph =0,0,0,0,0,0
        for zc in range(len(zca)):
            aaqi =zip_dict[zca[zc]]['AQI'][ks]['AVE_PM_2.5']
            maqi =zip_dict[zca[zc]]['AQI'][ks]['MAX_PM_2.5']
            aveqa = aveq + w_zca[zc]*aaqi
            maxq = max([maxq,maqi])
            aveqp = aveq + w_zcp[zc]*aaqi
            leva = level_AQI(calc_AQI(aaqi))
            levm = level_AQI(calc_AQI(maqi))
            if leva <=1:
                ag = ag + w_zca[zc]
                pg = pg + w_zcp[zc]
            elif leva <=2:
                amod = amod + w_zca[zc]
                pmod = pmod + w_zcp[zc]
            elif leva <=3:
                auhsg = auhsg + w_zca[zc]
                puhsg = puhsg + w_zcp[zc]
            elif leva <=4:
                auh = auh + w_zca[zc]
                puh = puh + w_zcp[zc]
            elif leva <=5:
                avuh = avuh + w_zca[zc]
                pvuh = pvuh + w_zcp[zc]
            else:
                ah = ah + w_zca[zc]
                ph = ph + w_zcp[zc]
            if levm <=1:
                mag = mag + w_zca[zc]
                mpg = mpg + w_zcp[zc]
            elif levm <=2:
                mamod = mamod + w_zca[zc]
                mpmod = mpmod + w_zcp[zc]
            elif levm <=3:
                mauhsg = mauhsg + w_zca[zc]
                mpuhsg = mpuhsg + w_zcp[zc]
            elif levm <=4:
                mauh = mauh + w_zca[zc]
                mpuh = mpuh + w_zcp[zc]
            elif levm <=5:
                mavuh = mavuh + w_zca[zc]
                mpvuh = mpvuh + w_zcp[zc]
            else:
                mah = mah + w_zca[zc]
                mph = mph + w_zcp[zc]
        # Writing totals
        BA[ks]['AREA_AVE_PM_2.5'] = aveqa
        BA[ks]['AREA_24hr_AQI'] = calc_AQI(aveqa)
        BA[ks]['AREA_AQI_LEVEL'] = level_AQI(BA[ks]['AREA_24hr_AQI'])
        BA[ks]['AREA_GOOD'] =ag
        BA[ks]['AREA_MOD'] =amod
        BA[ks]['AREA_UHSG'] =auhsg
        BA[ks]['AREA_UH'] =auh
        BA[ks]['AREA_VUH'] =avuh
        BA[ks]['AREA_HAZ'] =ah
        BA[ks]['AREA_GOOD_MAX'] =mag
        BA[ks]['AREA_MOD_MAX'] =mamod
        BA[ks]['AREA_UHSG_MAX'] =mauhsg
        BA[ks]['AREA_UH_MAX'] =mauh
        BA[ks]['AREA_VUH_MAX'] =mavuh
        BA[ks]['AREA_HAZ_MAX'] =mah
        BA[ks]['POP_AVE_PM_2.5'] = aveqp
        BA[ks]['POP_24hr_AQI'] = calc_AQI(aveqp)
        BA[ks]['POP_AQI_LEVEL'] = level_AQI(BA[ks]['POP_24hr_AQI'])
        BA[ks]['POP_GOOD'] =pg
        BA[ks]['POP_MOD'] =pmod
        BA[ks]['POP_UHSG'] =puhsg
        BA[ks]['POP_UH'] =puh
        BA[ks]['POP_VUH'] =pvuh
        BA[ks]['POP_HAZ'] =ph
        BA[ks]['POP_GOOD_MAX'] =mpg
        BA[ks]['POP_MOD_MAX'] =mpmod
        BA[ks]['POP_UHSG_MAX'] =mpuhsg
        BA[ks]['POP_UH_MAX'] =mpuh
        BA[ks]['POP_VUH_MAX'] =mpvuh
        BA[ks]['POP_HAZ_MAX'] =mph
        BA[ks]['MAX_PM_2.5'] = maxq
        BA[ks]['Max_AQI'] = calc_AQI(maxq)
        BA[ks]['AQI_LEVEL_MAX'] = level_AQI(BA[ks]['Max_AQI'] )

# %%
BA_table = pd.DataFrame.from_dict(BA,orient='index')
BA_table.head(10)
# Out:
#             AREA_AVE_PM_2.5  AREA_24hr_AQI  AREA_AQI_LEVEL  AREA_GOOD  \
# 2015-01-01        34.572643             98               2   0.075346
# 2015-01-02        34.515800             98               2   0.053861
# 2015-01-03        34.558838             98               2   0.053861
# 2015-01-04        34.483318             98               2   0.053861
# 2015-01-05        34.442680             98               2   0.071026
# 2015-01-06        34.227198             98               2   0.111207
# 2015-01-07        34.298171             98               2   0.183736
# 2015-01-08        34.217453             98               2   0.143564
# 2015-01-09        34.275434             98               2   0.143564
# 2015-01-10        34.390744             98               2   0.071026
#
#             AREA_MOD  AREA_UHSG   AREA_UH  AREA_VUH  AREA_HAZ  AREA_GOOD_MAX  \
# 2015-01-01  0.924654          0  0.000000       0.0       0.0       0.071026
# 2015-01-02  0.902882          0  0.043257       0.0       0.0       0.000000
# 2015-01-03  0.903650          0  0.042489       0.0       0.0       0.000000
# 2015-01-04  0.946139          0  0.000000       0.0       0.0       0.000000
# 2015-01-05  0.913337          0  0.015636       0.0       0.0       0.017165
# 2015-01-06  0.882551          0  0.006242       0.0       0.0       0.040181
# 2015-01-07  0.800628          0  0.015636       0.0       0.0       0.000000
# 2015-01-08  0.803385          0  0.053051       0.0       0.0       0.053861
# 2015-01-09  0.840800          0  0.015636       0.0       0.0       0.053861
# 2015-01-10  0.870081          0  0.058893       0.0       0.0       0.000000
#
#             ...  POP_HAZ  POP_GOOD_MAX  POP_MOD_MAX  POP_UHSG_MAX  POP_UH_MAX  \
# 2015-01-01  ...      0.0      0.006689     0.260327             0    0.478674
# 2015-01-02  ...      0.0      0.000000     0.674547             0    0.268862
# 2015-01-03  ...      0.0      0.000000     0.210978             0    0.421876
# 2015-01-04  ...      0.0      0.000000     0.061115             0    0.879553
# 2015-01-05  ...      0.0      0.000084     0.496866             0    0.384723
# 2015-01-06  ...      0.0      0.001738     0.280627             0    0.402321
# 2015-01-07  ...      0.0      0.000000     0.624852             0    0.373670
# 2015-01-08  ...      0.0      0.006605     0.035344             0    0.507214
# 2015-01-09  ...      0.0      0.006605     0.304050             0    0.503059
# 2015-01-10  ...      0.0      0.000000     0.847920             0    0.090549
#
#             POP_VUH_MAX  POP_HAZ_MAX  MAX_PM_2.5  Max_AQI  AQI_LEVEL_MAX
# 2015-01-01     0.254310          0.0       388.0      426              6
# 2015-01-02     0.056591          0.0       388.0      426              6
# 2015-01-03     0.367146          0.0       388.0      426              6
# 2015-01-04     0.059332          0.0       388.0      426              6
# 2015-01-05     0.118326          0.0       388.0      426              6
# 2015-01-06     0.315313          0.0       388.0      426              6
# 2015-01-07     0.001478          0.0       388.0      426              6
# 2015-01-08     0.450838          0.0       388.0      426              6
# 2015-01-09     0.186286          0.0       388.0      426              6
# 2015-01-10     0.061531          0.0       388.0      426              6
#
# [10 rows x 33 columns]

# %%
BA_table.to_csv('Data/BA_AQI_SUMMARY.csv', index=False)
